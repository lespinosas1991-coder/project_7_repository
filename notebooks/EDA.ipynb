# %% [markdown]
# Análisis Exploratorio de Datos de Vehículos.
#
# Descripción del Proyecto:
#
# Utilizando un conjunto de datos de anuncios de automóviles (vehicles_us.csv), este conjunto de datos contiene información sobre las ventas de automóviles usados, como precio, año del modelo, modelo, estado del vehículo, número de cilindros, tipo de combustible, kilometraje, tipo de transmisión, color de la pintura, tracción en las cuatro ruedas, fecha de publicación y días de publicación.
#
# Para este proyecto, hice una aplicación Streamlit alojada en Render que permite a los usuarios interactuar con el conjunto de datos de anuncios de automóviles para obtener información sobre qué atributos de los vehículos pueden aumentar su valor en el mercado secundario. Mediante visualizaciones de datos, este proyecto busca obtener información sobre qué atributos tienen un impacto direccional en el precio y permite a los usuarios interactuar con los gráficos para obtener sus propios hallazgos.

# %% [markdown]
# # IMPORTAR LIBRERÍAS PARA ANÁLISIS.

# %%
# Import packages
import pandas as pd 
import streamlit as st
import plotly.express as px
import altair as alt

# %% [markdown]
# # LEER EL ARCHIVO.

# %%
vehicles = pd.read_csv('/Users/luisespinosa/Documentos/DATA_SCIENCE/TRIPLETEN/SPRINT_VII/notebooks/vehicles_us.csv')

# %%
vehicles.info()

vehicles.describe(include='all')

vehicles.head()

vehicles.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB
# price               0
# model_year       3619
# model               0
# condition           0
# cylinders        5260
# fuel                0
# ...

# %% [markdown]
# Hay valores faltantes en los siguientes campos: model_year, cylinders, odometer, paint_color, is_4wd.
#
# year_model: Se reemplazarán los valores nulos por 0.
# cylinders: Se reemplazarán con el valor medio del mismo tipo de vehículo vendido.
# odometer: Se reemplazarán odometer con el valor medio del mismo tipo de vehículo vendido. Dado que odómetro debe ser un número entero y que 0 representa un coche nuevo, estableceré el valor faltante con un valor promedio de todos los vehículos vendidos en el conjunto de datos del mismo tipo de vehículo. paint_color: Se reemplazarán los valores nulos con la cadena "desconocido" y convertiré paint_color en una cadena.
# is_4wd: Se Reemplazarán los valores nulos con 0. Actualmente, cuando is_4wd es 1, significa que el vehículo tiene tracción en las cuatro ruedas. Si es cero, podemos asumir que el vehículo no tiene tracción en las cuatro ruedas o que el valor es desconocido.

# %% [markdown]
# # LLENAR VALORES AUSENTES.

# %%
vehicles['model_year'] = vehicles['model_year'].fillna(0)

vehicles['cylinders'] = vehicles['cylinders'].fillna(vehicles.groupby('type')['cylinders'].transform('median'))

vehicles['odometer'] = vehicles['odometer'].fillna(vehicles.groupby('type')['odometer'].transform('median'))

vehicles['paint_color'] = vehicles['paint_color'].fillna('desconocido')

vehicles['is_4wd'] = vehicles['is_4wd'].fillna(0)

vehicles.isna().sum()
# Out:
# price           0
# model_year      0
# model           0
# condition       0
# cylinders       0
# fuel            0
# odometer        0
# transmission    0
# type            0
# paint_color     0
# is_4wd          0
# date_posted     0
# days_listed     0
# dtype: int64

# %% [markdown]
# # CONVERTIR TIPOS DE DATOS.

# %%
vehicles['price'] = vehicles['price'].astype(float)
vehicles['model_year'] = vehicles['model_year'].astype('Int64')
vehicles['model'] = vehicles['model'].astype(str)
vehicles['condition'] = vehicles['condition'].astype(str)
vehicles['cylinders'] = vehicles['cylinders'].astype('Int64') 
vehicles['fuel'] = vehicles['fuel'].astype(str)
vehicles['odometer'] = vehicles['odometer'].astype(float)
vehicles['transmission'] = vehicles['transmission'].astype(str)
vehicles['type'] = vehicles['type'].astype(str)
vehicles['paint_color'] = vehicles['paint_color'].astype(str)
vehicles['is_4wd'] = vehicles['is_4wd'].astype('Int64')
vehicles['date_posted'] = vehicles['date_posted'].astype('datetime64[ns]') 
vehicles['days_listed'] = vehicles['days_listed'].astype('Int64')

vehicles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  float64
#  1   model_year    51525 non-null  Int64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     51525 non-null  Int64
#  5   fuel          51525 non-null  object
#  6   odometer      51525 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   51525 non-null  object
#  10  is_4wd        51525 non-null  Int64
#  11  date_posted   51525 non-null  datetime64[ns]
#  12  days_listed   51525 non-null  Int64
# dtypes: Int64(4), datetime64[ns](1), float64(2), object(6)
# memory usage: 5.3+ MB

# %% [markdown]
# # Crear Visualizaciones:

# %%
# Configurar parámetros para el diagrama de dispersión:

fig = px.scatter(vehicles, x="cylinders", y="price", color="condition", symbol="condition", hover_data=['model'])

# Mostrar diagrama de dispersión:

fig.show()

# %% [markdown]
# # CREAR HISTOGRAMA:

# %%
# Configurar parámetros para el Histograma:

fig = px.histogram(vehicles, x="model_year", color="type")

# Mostrar Histograma:

fig.show()
